# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
import pandas as pd
from paths import dataDir
file_path = dataDir / "raw" / "ibmchurn.csv"
df = pd.read_csv(file_path)
